# %%
# My Project for completion of face one of my python training. The project is developed for a banking system



# TagBiz  Bank
class TagBiz_Bank:
    number_of_branch=0
    def __init__(self,branch=1,share_value=0.0,share_amount=0):
        self.branch=branch
        self.share_value=share_value
        self.share_amount=share_amount
        TagBiz_Bank.number_of_branch=TagBiz_Bank.number_of_branch+1
        
    def buy_shares(self):
        share=input("How much share do you want to buy: ")
        if self.share_amount>=100000:
            self.share_value=self.share_amount/100
            print(f"You have successfully buy {self.share_amount} and the value of your share is {self.share_value}")
        else:
            print(f"The is no value for the share amount {self.share_amount} you entered")      
    

class Customer(TagBiz_Bank):
    def __init__(self, balance,branch=1, share_value=0.0,share_amount=0,isActive=True, isInActive=False):
        super().__init__(branch,share_value,share_amount)
        import random
        self.balance=balance
        self.isActive=isActive
        self.isInActive=isInActive
        self.account_number= random.randint(576213876,576999999)
        print("-------Welcome To TagBiz Bank, Our Customer Satisfaction is our priority--------")
        new_customer_firstname=input("Thank you for your interest in TagBiz Bank. Please Enter your first name to proceed: ")
        new_customer_middlename=input("Enter your middle name: ")
        new_customer_lastname=input("Enter your last name name: ")
        phnoe_number=int(input("Enter your phone numebr: "))
        address=input("Enter your house address: ")
        email=input("Enter your email address: ")
        password=input("Enter your password")
        print(f"Thank you {new_customer_firstname} {new_customer_middlename} {new_customer_lastname}, you have sucessfully open an account with TagBiz Bank and your account number is {self.account_number}")
        
    def exchange_money(self):
        if self.isActive==True:
            try:
                exchange=input("What currency do you want to exchange to")
                if exchange.lower()=="dollar":
                    exchange_amount=int(input("How much do you want to exchange"))
                    print(f"The exchnage rate of dollar is 1630 per dollar and {exchange_amount} will be ${exchange_amount/1630} dollar")
                elif exchange.lower()=="euro":
                    exchange_amount=int(input("How much do you want to exchange"))
                    print(f"The exchnage rate of dollar is 2000 per euroand {exchange_amount} is will be  E{exchange_amount/2000} euro")
                elif exchange.lower()=="pounds":
                    exchange_amount=int(input("How much do you want to exchange"))
                    print(f"The exchnage rate of dollar is 2500 per pounda and {exchange_amount} is will be P{exchange_amount/2500}")
                    self.balance=self.balance-exchange_amount
                    print(f"Your balance remain {self.balance}")
                else:
                    print(f"We do not accept exchange for the type of currency you enter")
            except:
                print("invaild")  
        else:
            print("Please activate your acount, this account is dormant")
     
    def transfer_money(self):
        if (self.isActive==True and self.balance !=0) and self.balance!= -(self.balance):
            transfer = input("Enter the amount you want to transfer: ")
            try:
                transfer=int(transfer) 
                if transfer<= self.balance: 
                    recipient=input("Enter the recipient details: ")
                    print(f"you have successfully transfer {transfer} to {recipient}")
                else:
                    print("Insuffient amount")
            except:
                print("invalid input")
        else:
            print("Please active your acount, this adollarcoount is dormant")

    def pay_bill(self):
        bill=input("Enter the bill amount you want to pay")
        if self.balance>=bill:
            self.balance=self.balance-bill
            print(f"You have successfully pay {bill} for you bill and the balance in your account is {self.balance}")
        else:
            print("You have insufficient balance in your account")
            
    def withdraw(self):
        amount_to_withdraw=int(input("Enter the amount you want to withdraw: "))
        if self.balance>=amount_to_withdraw and self.balance!= -(self.balance):
            self.balance=self.balance-amount_to_withdraw
            print(f"You made a withdraw of #{amount_to_withdraw} from your account and your total balance is #{self.balance}")
        else:
            print("You can not withdraw amount greater than your balance or amount less that 0")
            
        
    def deposit(self):
        if self.isActive==True:
            amount_to_deposit=input("Enter the amount you want to deposit: ")
            if amount_to_deposit != -(amount_to_deposit):
                self.balance=self.balance + amount_to_deposit
                print(f"You successfully make a deposit of {amount_to_deposit} and your new balance is {self.balance}")
            else:
                print("You can not deposit or withdraw a negative amount")
        else:
            print("invalid")
        

    def takeAloan(self):
        if self.isActive ==True and self.balance>15000000:
            print("You are a premium customer, so qualify to get a loan of up to 30M")
        else:  
            print("You are only qualify to take loan below 30M")
        
class Staff(TagBiz_Bank):
    staff_number=0
    def __init__(self,loan,balance,branch=1,share_value=0.0,share_amount=0,isActive=True):
         super().__init__(branch, share_value,share_amount)
         self.loan=loan
         self.isActive=isActive
         self.balance=balance
         Staff.staff_number+=1 
    def takeAloan_for_staff(self):
        if self.isActive ==True and self.loan==0:
            amount=int(input("Enter the loan amount you want"))
            print("Your loan request has been recieve and is been processed")
            self.balance=self.balance+amount
            self.loan=self.loan + (amount*0.1)+amount
            print(f"Your loan request of {amount} has been successfully sent to your account, your current balance is now {self.balance}  while your repayment loan is {self.loan}")
            
        elif self.loan!=0:
            print("Sorry, you still have an active loan for pay")
        else:
            print("You are not Qualify to take a loan")
        
class Manager(Staff):
    def __init__(self,loan,balance,account_id,isActive=True):
        super().__init__(loan,balance,isActive=True)
        self.account_id=account_id
        def payforflight(self):
            flight_payment=input("Enter the amount you want to pay for the flight")
            if self.balance >= flight_payment and self.balance!= -(self.balance):
                self.balance=self.balance-flight_payment
                print(f"{self.account_id} you have successfully paind {flight_payment} as the flight ticket and the balance in you account is {self.balance}")
            else:
                print("You have insufficient funds or you've entered a negative number")          
    
    
class CEO(Manager):
    def __init__(self,loan,balance,account_id,department):
        super().__init__(loan,balance,account_id)
        self.department=department
    def sack_manager(self):
        sack_staff=input("Enter the ID of the manager you want to sack: ")
        print(f" You have sacked {sack_staff}, they've been directed to get their letter from the branch secretary")
    def number_of_branch(self):
        print(f"We currently have {TagBiz_Bank.number_of_branch} number of branches")
        
    def view_staff_number(self):
        print(f"There are {Staff.staff_number} total number of staff")
